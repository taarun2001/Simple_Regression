# %% [markdown]
# # Simple Linear regression

# %% [markdown]
# ### Machine Learning Pipeline
#
# >Data Collection
#
# >Data Preparation(Data Cleaning)
#
# >Splitting Dataset(Vertically and horizontally)
#
# >Model Building (choosing related model on dataset)
#
# >Evaluating model

# %% [markdown]
# #### Model Building
#
# >import required libraries
#
# >import dataset
#
# >clean the dataset and analyse the dataset
#
# >split data into training and testing set
#
# >choose the model(i.e algorithm..)
#
# >trian the model(fit the model based on the dataset)
#
# >Evakuating the model

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("Salary_dataset.csv")

# %%
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### we have no duplicates

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.isna().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# #### there is no null values

# %%
# remove unwanted columns
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
plt.scatter(df["YearsExperience"],df["Salary"])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Experience Vs Salaray")
plt.plot()
# Out:
# []

# %%
from sklearn.model_selection import train_test_split

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
x=df.iloc[:,0]
y=df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
x_train
# Out:
# 26     9.6
# 3      2.1
# 24     8.8
# 22     8.0
# 23     8.3
# 4      2.3
# 2      1.6
# 25     9.1
# 6      3.1
# 18     6.0
# 13     4.2
# 7      3.3
# 27     9.7
# 1      1.4
# 16     5.2
# 0      1.2
# 15     5.0
# 29    10.6
# 28    10.4
# 9      3.8
# 8      3.3
# 12     4.1
# 11     4.1
# 5      3.0
# Name: YearsExperience, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train.values
# Out:
# array([ 9.6,  2.1,  8.8,  8. ,  8.3,  2.3,  1.6,  9.1,  3.1,  6. ,  4.2,
#         3.3,  9.7,  1.4,  5.2,  1.2,  5. , 10.6, 10.4,  3.8,  3.3,  4.1,
#         4.1,  3. ])

# %%
x_train
# Out:
# 26     9.6
# 3      2.1
# 24     8.8
# 22     8.0
# 23     8.3
# 4      2.3
# 2      1.6
# 25     9.1
# 6      3.1
# 18     6.0
# 13     4.2
# 7      3.3
# 27     9.7
# 1      1.4
# 16     5.2
# 0      1.2
# 15     5.0
# 29    10.6
# 28    10.4
# 9      3.8
# 8      3.3
# 12     4.1
# 11     4.1
# 5      3.0
# Name: YearsExperience, dtype: float64

# %%
lr = LinearRegression()
lr.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
x_train.values
# Out:
# array([ 9.6,  2.1,  8.8,  8. ,  8.3,  2.3,  1.6,  9.1,  3.1,  6. ,  4.2,
#         3.3,  9.7,  1.4,  5.2,  1.2,  5. , 10.6, 10.4,  3.8,  3.3,  4.1,
#         4.1,  3. ])

# %%
model_predict=lr.predict(x_test.values.reshape(-1,1))

# %%
model_predict
# Out:
# array([75075.50510972, 91874.8056381 , 62009.38247653, 81608.56642631,
#        67609.14931932, 89074.92221671])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
r2_score(y_test,model_predict)
# Out:
# 0.7616681465472098
